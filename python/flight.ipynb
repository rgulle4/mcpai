# %%
import json
import requests

api_key = "AIzaSyCxC53nAkMaeEDWFCmCT8JXOA8Qcv8ej0g"
url = "https://www.googleapis.com/qpxExpress/v1/trips/search?key=" + api_key
headers = {'content-type': 'application/json'}

origin = "MSY"
destination = "ATL"
date = "2016-11-28"
maxPrice = "USD300"
earliestTime = ""
latestTime = ""

params = {
  "request": {
    "slice": [
      {
        "origin": origin,
        "destination": destination,
        "date": date,
        "permittedDepartureTime": {
          "earliestTime": earliestTime,
          "latestTime": latestTime
        }
      }
    ],
    "passengers": {
      "adultCount": 1
    },
    "solutions": 20,
    "maxPrice": maxPrice,
    "refundable": False
  }
}

response = requests.post(url, data=json.dumps(params), headers=headers)
data = response.json()
sortJson = json.dumps(data, sort_keys=True,
                indent=2, separators=(',', ':'))

print(sortJson)
# Out:
# {
#   "kind":"qpxExpress#tripsSearch",
#   "trips":{
#     "data":{
#       "aircraft":[
#         {
#           "code":"319",
#           "kind":"qpxexpress#aircraftData",
#           "name":"Airbus A319"
#         },
#         {
#           "code":"320",
#           "kind":"qpxexpress#aircraftData",
#           "name":"Airbus A320"
#         },
#         {
#           "code":"738",
#           "kind":"qpxexpress#aircraftData",
#           "name":"Boeing 737"
#         },
#         {
#           "code":"73G",
#           "kind":"qpxexpress#aircraftData",
#           "name":"Boeing 737"
#         },
#         {
#           "code":"CR7",
#           "kind":"qpxexpress#aircraftData",
#           "name":"Canadair RJ 700"
#         },
#         {
#           "code":"E70",
#           "kind":"qpxexpress#aircraftData",
#           "name":"Embraer RJ-170"
#         },
#         {
#           "code":"E7W",
#           "kind":"qpxexpress#aircraftData",
#           "name":"Embraer RJ-175"
# ...

# %%
for j in range(0, len(data['trips']['tripOption'])):
    print ('Solution', j)
    print ('Sale Total', data['trips']['tripOption'][j]['saleTotal'])
    print ('Time Total', data['trips']['tripOption'][j]['slice'][0]['duration'])
    for i in range(0, len(data['trips']['tripOption'][j]['slice'][0]['segment'])):
        print (data['trips']['tripOption'][j]['slice'][0]['segment'][i]['flight']['carrier'], 
               data['trips']['tripOption'][j]['slice'][0]['segment'][i]['flight']['number'],
               data['trips']['tripOption'][j]['slice'][0]['segment'][i]['leg'][0]['origin'], 
               data['trips']['tripOption'][j]['slice'][0]['segment'][i]['leg'][0]['departureTime'],
               data['trips']['tripOption'][j]['slice'][0]['segment'][i]['leg'][0]['destination'], 
               data['trips']['tripOption'][j]['slice'][0]['segment'][i]['leg'][0]['arrivalTime'])
    print ("")
# Out:
# Solution 0
# Sale Total USD198.60
# Time Total 312
# UA 1136 MSY 2016-11-28T07:11-06:00 IAH 2016-11-28T08:34-06:00
# UA 6287 IAH 2016-11-28T10:16-06:00 ATL 2016-11-28T13:23-05:00
#
# Solution 1
# Sale Total USD198.60
# Time Total 274
# UA 740 MSY 2016-11-28T15:15-06:00 IAH 2016-11-28T16:40-06:00
# UA 6104 IAH 2016-11-28T17:45-06:00 ATL 2016-11-28T20:49-05:00
#
# Solution 2
# Sale Total USD198.60
# Time Total 273
# UA 1077 MSY 2016-11-28T07:50-06:00 IAH 2016-11-28T09:12-06:00
# UA 6287 IAH 2016-11-28T10:16-06:00 ATL 2016-11-28T13:23-05:00
#
# Solution 3
# Sale Total USD198.60
# Time Total 359
# UA 740 MSY 2016-11-28T15:15-06:00 IAH 2016-11-28T16:40-06:00
# UA 6148 IAH 2016-11-28T19:10-06:00 ATL 2016-11-28T22:14-05:00
#
# Solution 4
# Sale Total USD198.60
# Time Total 353
# UA 1117 MSY 2016-11-28T06:30-06:00 IAH 2016-11-28T07:51-06:00
# UA 6287 IAH 2016-11-28T10:16-06:00 ATL 2016-11-28T13:23-05:00
#
# Solution 5
# Sale Total USD198.60
# Time Total 350
# ...

# %%
json.dumps(params)
# Out:
# '{"request": {"slice": [{"date": "2016-11-28", "origin": "MSY", "destination": "ATL", "permittedDepartureTime": {"earliestTime": "", "latestTime": ""}}], "solutions": 20, "passengers": {"adultCount": 1}, "maxPrice": "USD300", "refundable": false}}'

# %%
response = requests.post(url, data=json.dumps(params), headers=headers)

# %%
response.url
# Out:
# 'https://www.googleapis.com/qpxExpress/v1/trips/search?key=AIzaSyCxC53nAkMaeEDWFCmCT8JXOA8Qcv8ej0g'
